# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(-90.000,90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
cities = []

lats = np.random.uniform(-90.000,90.000, size=1500)
lngs = np.random.uniform(-90.000,90.000, size=1500)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['bambous virieux',
#  'sorvag',
#  'dikson',
#  'cape town',
#  'oskarshamn',
#  'banda aceh',
#  'port elizabeth',
#  'inhambane',
#  'taolanaro',
#  'hermanus',
#  'amderma',
#  'busselton',
#  'buncrana',
#  'wajir',
#  'binga',
#  'faya',
#  'chuy',
#  'narsaq',
#  'rehoboth',
#  'ilulissat',
#  'loukhi',
#  'sharjah',
#  'saint anthony',
#  'ilebo',
#  'vila velha',
#  'talnakh',
#  'tsihombe',
#  'bjala',
#  'kondinskoye',
#  'turukhansk',
#  'ancud',
#  'east london',
#  'zaida',
#  'bubaque',
#  'luderitz',
#  'port alfred',
#  'sao joao da barra',
#  'garissa',
#  'clyde river',
#  'gobabis',
#  'caravelas',
#  'bredasdorp',
#  'ribeira grande',
#  'najran',
#  'belushya guba',
#  'nemours',
#  'jamestown',
#  'dwarka',
#  'nador',
#  'ushuaia',
#  'tasiilaq',
#  'pozhva',
#  'bhatkal',
#  'trairi',
#  'cabedelo',
#  'ambilobe',
#  'adrar',
#  'altamira',
#  'tyukalinsk',
#  'saint george',
#  'mar del plata',
#  'illoqqortoormiut',
#  'djambala',
#  'presidencia roque saenz pena',
#  'kemijarvi',
#  'talawdi',
#  'huanuni',
#  'sinnamary',
#  'san andres',
#  'ozgon',
#  'pisco',
#  'victoria',
#  'oranjemund',
#  'nouadhibou',
#  'vardo',
#  'fasa',
#  'nyimba',
#  'porbandar',
#  'geraldton',
#  'diego de almagro',
#  'cayenne',
#  'canico',
#  'hun',
#  'hithadhoo',
#  'dingle',
#  'kjollefjord',
#  'peniche',
#  'arraial do cabo',
#  'the valley',
#  'villazon',
#  'longyearbyen',
#  'saint-pierre',
#  'hobyo',
#  'bengkulu',
#  'rujewa',
#  'punta arenas',
#  'sorland',
#  'maniitsoq',
#  'thinadhoo',
#  'nanortalik',
#  'tres arroyos',
#  'berlevag',
#  'aljezur',
#  'akdepe',
#  'upernavik',
#  'rio gallegos',
#  'ballina',
#  'sistranda',
#  'qaanaaq',
#  'bilma',
#  'susehri',
#  'taoudenni',
#  'warqla',
#  'roald',
#  'mahebourg',
#  'saint-philippe',
#  'mungwi',
#  'sept-iles',
#  'ciudad bolivar',
#  'saravena',
#  'montbrison',
#  'bati',
#  'rocha',
#  'lai',
#  'pamplona',
#  'darnah',
#  'oxford',
#  'rafsanjan',
#  'coquimbo',
#  'acarau',
#  'paamiut',
#  'thompson',
#  'asyut',
#  'bathsheba',
#  'belvedere marittimo',
#  'namibe',
#  'glace bay',
#  'belmonte',
#  'gangotri',
#  'sandviken',
#  'saldanha',
#  'fiumicino',
#  'lerwick',
#  'mehamn',
#  'zermatt',
#  'boa vista',
#  'paradwip',
#  'manama',
#  'lagoa',
#  'osinki',
#  'rio grande',
#  'wageningen',
#  'angra',
#  'kismayo',
#  'oktyabrskiy',
#  'beloha',
#  'ponta do sol',
#  'brae',
#  'doctor pedro p. pena',
#  'gibara',
#  'ushtobe',
#  'dubai',
#  'hambantota',
#  'gambela',
#  'hamina',
#  'talara',
#  'morondava',
#  'antalaha',
#  'bam',
#  'kautokeino',
#  'cleethorpes',
#  'bandarbeyla',
#  'torbay',
#  'linhares',
#  'comodoro rivadavia',
#  'port shepstone',
#  'chake chake',
#  'grindavik',
#  'ostrovnoy',
#  'panaba',
#  'zomin',
#  'santa rosa',
#  'bayan',
#  'plettenberg bay',
#  'palmas bellas',
#  'hamilton',
#  'qena',
#  'chinsali',
#  'castro',
#  'tabas',
#  'buraydah',
#  'umzimvubu',
#  'lyuban',
#  'kuche',
#  'karkaralinsk',
#  'marsa matruh',
#  'san pedro de ycuamandiyu',
#  'damietta',
#  'mozarlandia',
#  'qaqortoq',
#  'ust-koksa',
#  'barsovo',
#  'morristown',
#  'attawapiskat',
#  'carnarvon',
#  'lethem',
#  'minab',
#  'lesogorskiy',
#  'yar',
#  'sao miguel do araguaia',
#  'riyadh',
#  'klaksvik',
#  'cockburn town',
#  'tshikapa',
#  'araouane',
#  'georgetown',
#  'brandon',
#  'quatre cocos',
#  'nalut',
#  'kangaatsiaq',
#  'axim',
#  'nouakchott',
#  'zambezi',
#  'saint-leu',
#  'port blair',
#  'codrington',
#  'guarapari',
#  'maudaha',
#  'palmares do sul',
#  'sal rei',
#  'ipameri',
#  'joao pinheiro',
#  'albany',
#  'afua',
#  'barentsburg',
#  'tazovskiy',
#  'erlangen',
#  'verkhnyaya inta',
#  'moyo',
#  'rondonopolis',
#  'yar-sale',
#  'salo',
#  'temba',
#  'sambava',
#  'vigia',
#  'charlestown',
#  'ji-parana',
#  'aleksandrov gay',
#  'cabo rojo',
#  'kostomuksha',
#  'cidreira',
#  'volkach',
#  'coihueco',
#  'lodingen',
#  'marystown',
#  'la peca',
#  'karistos',
#  'chicama',
#  'catia la mar',
#  'kasba',
#  'concarneau',
#  'stornoway',
#  'oistins',
#  'sur',
#  'gamba',
#  'luxor',
#  'salta',
#  'trelew',
#  'saint-georges',
#  'ventspils',
#  'florida',
#  'dhankuta',
#  'puntarenas',
#  'aksu',
#  'alibag',
#  'santa isabel do rio negro',
#  'cordoba',
#  'atbasar',
#  'bababe',
#  'vila franca do campo',
#  'baikunthpur',
#  'los llanos de aridane',
#  'grand gaube',
#  'koygorodok',
#  'whittlesea',
#  'jaisalmer',
#  'togur',
#  'ketou',
#  'matagami',
#  'iqaluit',
#  'abu dhabi',
#  'kattivakkam',
#  'bara',
#  'wajid',
#  'vestmannaeyjar',
#  'praia',
#  'salalah',
#  'kruisfontein',
#  'abu samrah',
#  'bay roberts',
#  'jalu',
#  'kudahuvadhoo',
#  'ayagoz',
#  'ponta delgada',
#  'saint-augustin',
#  'teguise',
#  'rosendal',
#  'rjukan',
#  'changji',
#  'tessalit',
#  'chapais',
#  'shiraz',
#  'kushmurun',
#  'sao filipe',
#  'zlobin',
#  'boksitogorsk',
#  'foldeak',
#  'alegrete',
#  'shupiyan',
#  'lucapa',
#  'buba',
#  'redondela',
#  'sakakah',
#  'lusambo',
#  'solwezi',
#  'humaita',
#  'les cayes',
#  'san cristobal',
#  'salinopolis',
#  'agirish',
#  'uhlove',
#  'muravlenko',
#  'konevo',
#  'mbanza-ngungu',
#  'alto araguaia',
#  'almeirim',
#  'francistown',
#  'skibbereen',
#  'taormina',
#  'lukovetskiy',
#  'mananara',
#  'tumannyy',
#  'banikoara',
#  'aswan',
#  'savannah bight',
#  'san pedro',
#  'touros',
#  'artyom',
#  'sisimiut',
#  'hvolsvollur',
#  'tapes',
#  'porto santo',
#  'kaya',
#  'belyy yar',
#  'ternitz',
#  'camocim',
#  'el astillero',
#  'san lorenzo',
#  'bonavista',
#  'goderich',
#  'nantucket',
#  'kotido',
#  'puertollano',
#  'cap malheureux',
#  'talcahuano',
#  'vesoul',
#  'narasannapeta',
#  'puerto del rosario',
#  'bar harbor',
#  'kalabo',
#  'blankenberge',
#  'grootfontein',
#  'savinskiy',
#  'ostersund',
#  'sile',
#  'werder',
#  'zwedru',
#  'lodwar',
#  'itarema',
#  'revda',
#  'sadovoye',
#  'chik',
#  'burica',
#  'madingou',
#  'mahajanga',
#  'ilhabela',
#  'amapa',
#  'tibati',
#  'kankan',
#  'aflu',
#  'ayia galini',
#  'padang',
#  'nola',
#  'uruzgan',
#  'stepnyak',
#  'awjilah',
#  'balsas',
#  'alipur chatha',
#  'kavaratti',
#  'cetraro',
#  'thaba-tseka',
#  'mezen',
#  'azul',
#  'norton',
#  'port-gentil',
#  'mufulira',
#  'calama',
#  'tarko-sale',
#  'anloga',
#  'babanusah',
#  'dahuk',
#  'camacha',
#  'pangnirtung',
#  'matane',
#  'samana',
#  'lake shore',
#  'xai-xai',
#  'hunza',
#  'kobojango',
#  'toropets',
#  'bahia blanca',
#  'oxapampa',
#  'nata',
#  'grand river south east',
#  'shoranur',
#  'urengoy',
#  'chapada dos guimaraes',
#  'sawakin',
#  'aden',
#  'lima',
#  'pero pinheiro',
#  'bolu',
#  'yambio',
#  'luleburgaz',
#  'arlit',
#  'bridgetown',
#  'sinkat',
#  'catamarca',
#  'manavgat',
#  'raga',
#  'metsovon',
#  'nahrin',
#  'akdagmadeni',
#  'ormara',
#  'moyale',
#  'kisangani',
#  'havre-saint-pierre',
#  'mitsamiouli',
#  'lokoja',
#  'raudeberg',
#  'arauco',
#  'san rafael',
#  'ossipee',
#  'azuaga',
#  'vuktyl',
#  'alenquer',
#  'chatsu',
#  'miquelon',
#  'maceio',
#  'mrirt',
#  'virginia beach',
#  'inongo',
#  'la asuncion',
#  'kulu',
#  'strezhevoy',
#  'agua branca',
#  'marfino',
#  'nuuk',
#  'karpathos',
#  'bustonkala',
#  'canto do buriti',
#  'ambovombe',
#  'sesheke',
#  'atasu',
#  'marevo',
#  'faro',
#  'igarka',
#  'kentau',
#  'sao joaquim',
#  'abeche',
#  'derbent',
#  'bentiu',
#  'galbshtadt',
#  'scarborough',
#  'rognan',
#  'olinda',
#  'meulaboh',
#  'kalengwa',
#  'louisbourg',
#  'ardrishaig',
#  'polunochnoye',
#  'tripoli',
#  'oksfjord',
#  'kidal',
#  'bastia',
#  'hofn',
#  'mutsamudu',
#  'jujuy',
#  'abha',
#  'husavik',
#  'jaque',
#  'jega',
#  'gat',
#  'souillac',
#  'laguna',
#  'gornopravdinsk',
#  'vyyezdnoye',
#  'goya',
#  'coihaique',
#  'honningsvag',
#  'kalomo',
#  'aviles',
#  'bria',
#  'port-cartier',
#  'razole',
#  'bonthe',
#  'katsiveli',
#  'leticia',
#  'shache',
#  'toliary',
#  'kulhudhuffushi',
#  'halvad',
#  'mokolo',
#  'veraval',
#  'gilgit',
#  'aracoiaba',
#  'ambodifototra',
#  'mouzakion',
#  'dibaya',
#  'richards bay',
#  'camopi',
#  'gari',
#  'queenstown',
#  'millbury',
#  'morbegno',
#  'karaul',
#  'paraibano',
#  'krasnyy oktyabr',
#  'concepcion',
#  'barbar',
#  'kasungu',
#  'lebu',
#  'inta',
#  'bongandanga',
#  'beyneu',
#  'luau',
#  'tutoia',
#  'naftah',
#  'ewo',
#  'moengo',
#  'takaungu',
#  'zeist',
#  'poselki',
#  'gewane',
#  'naryan-mar',
#  'aksarka',
#  'oxelosund',
#  'carauari',
#  'abnub',
#  'soyo',
#  'sussex',
#  'tukrah',
#  'melfi',
#  'aasiaat',
#  'porto novo',
#  'boditi',
#  'kisanga',
#  'den helder',
#  'sao borja',
#  'boo',
#  'tabou',
#  'ugoofaaru',
#  'bealanana',
#  'vestmanna',
#  'tarnogskiy gorodok',
#  'marathon',
#  'waddan',
#  'maragogi',
#  'fort-shevchenko',
#  'rawson',
#  'babadag',
#  'naliya',
#  'urucara',
#  'lebyazhye',
#  'tonota',
#  'ribas do rio pardo',
#  'kamenka',
#  'viedma',
#  'jawhar',
#  'kolosovka',
#  'uberaba',
#  'carutapera',
#  'cerrito',
#  'imbituba',
#  'aranos',
#  'butterworth',
#  'umm durman',
#  'galle',
#  'ratnapura',
#  'fakel',
#  'goure',
#  'road town',
#  'opuwo',
#  'dunda',
#  'le port',
#  'miranorte',
#  'sao felix do xingu',
#  'skalistyy',
#  'puerto armuelles',
#  'lisakovsk',
#  'muzhi',
#  'margate',
#  'tanhacu',
#  'ruswil',
#  'muisne',
#  'puunsi',
#  'calabozo',
#  'acari',
#  'benguela']

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Out:
# 619

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import OpenWeather_API_KEY

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop for cities
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | oskarshamn
# Processing Record 6 of Set 1 | banda aceh
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | inhambane
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | buncrana
# Processing Record 14 of Set 1 | wajir
# Processing Record 15 of Set 1 | binga
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | rehoboth
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | loukhi
# Processing Record 22 of Set 1 | sharjah
# Processing Record 23 of Set 1 | saint anthony
# Processing Record 24 of Set 1 | ilebo
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | bjala
# City not found. Skipping...
# Processing Record 29 of Set 1 | kondinskoye
# Processing Record 30 of Set 1 | turukhansk
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | zaida
# Processing Record 34 of Set 1 | bubaque
# Processing Record 35 of Set 1 | luderitz
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | sao joao da barra
# Processing Record 38 of Set 1 | garissa
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | gobabis
# Processing Record 41 of Set 1 | caravelas
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | najran
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | nemours
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | dwarka
# Processing Record 49 of Set 1 | nador
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | pozhva
# Processing Record 3 of Set 2 | bhatkal
# Processing Record 4 of Set 2 | trairi
# Processing Record 5 of Set 2 | cabedelo
# Processing Record 6 of Set 2 | ambilobe
# Processing Record 7 of Set 2 | adrar
# Processing Record 8 of Set 2 | altamira
# Processing Record 9 of Set 2 | tyukalinsk
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | djambala
# Processing Record 14 of Set 2 | presidencia roque saenz pena
# Processing Record 15 of Set 2 | kemijarvi
# Processing Record 16 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 2 | huanuni
# Processing Record 18 of Set 2 | sinnamary
# Processing Record 19 of Set 2 | san andres
# Processing Record 20 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | oranjemund
# Processing Record 24 of Set 2 | nouadhibou
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | fasa
# Processing Record 27 of Set 2 | nyimba
# Processing Record 28 of Set 2 | porbandar
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | diego de almagro
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | canico
# Processing Record 33 of Set 2 | hun
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | dingle
# Processing Record 36 of Set 2 | kjollefjord
# Processing Record 37 of Set 2 | peniche
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | the valley
# Processing Record 40 of Set 2 | villazon
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | hobyo
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | rujewa
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | sorland
# Processing Record 48 of Set 2 | maniitsoq
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | tres arroyos
# Processing Record 2 of Set 3 | berlevag
# Processing Record 3 of Set 3 | aljezur
# Processing Record 4 of Set 3 | akdepe
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | rio gallegos
# Processing Record 7 of Set 3 | ballina
# Processing Record 8 of Set 3 | sistranda
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | susehri
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 3 | roald
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | mungwi
# Processing Record 18 of Set 3 | sept-iles
# Processing Record 19 of Set 3 | ciudad bolivar
# Processing Record 20 of Set 3 | saravena
# Processing Record 21 of Set 3 | montbrison
# Processing Record 22 of Set 3 | bati
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | lai
# Processing Record 25 of Set 3 | pamplona
# Processing Record 26 of Set 3 | darnah
# Processing Record 27 of Set 3 | oxford
# Processing Record 28 of Set 3 | rafsanjan
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | acarau
# Processing Record 31 of Set 3 | paamiut
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | asyut
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | belvedere marittimo
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | glace bay
# Processing Record 38 of Set 3 | belmonte
# Processing Record 39 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 40 of Set 3 | sandviken
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | fiumicino
# Processing Record 43 of Set 3 | lerwick
# Processing Record 44 of Set 3 | mehamn
# Processing Record 45 of Set 3 | zermatt
# Processing Record 46 of Set 3 | boa vista
# Processing Record 47 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 3 | manama
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | osinki
# Processing Record 1 of Set 4 | rio grande
# Processing Record 2 of Set 4 | wageningen
# Processing Record 3 of Set 4 | angra
# City not found. Skipping...
# Processing Record 4 of Set 4 | kismayo
# Processing Record 5 of Set 4 | oktyabrskiy
# Processing Record 6 of Set 4 | beloha
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 4 | gibara
# Processing Record 11 of Set 4 | ushtobe
# Processing Record 12 of Set 4 | dubai
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | gambela
# Processing Record 15 of Set 4 | hamina
# Processing Record 16 of Set 4 | talara
# Processing Record 17 of Set 4 | morondava
# Processing Record 18 of Set 4 | antalaha
# Processing Record 19 of Set 4 | bam
# Processing Record 20 of Set 4 | kautokeino
# Processing Record 21 of Set 4 | cleethorpes
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | linhares
# Processing Record 25 of Set 4 | comodoro rivadavia
# Processing Record 26 of Set 4 | port shepstone
# Processing Record 27 of Set 4 | chake chake
# Processing Record 28 of Set 4 | grindavik
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | panaba
# Processing Record 31 of Set 4 | zomin
# Processing Record 32 of Set 4 | santa rosa
# Processing Record 33 of Set 4 | bayan
# Processing Record 34 of Set 4 | plettenberg bay
# Processing Record 35 of Set 4 | palmas bellas
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | qena
# Processing Record 38 of Set 4 | chinsali
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | tabas
# Processing Record 41 of Set 4 | buraydah
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | lyuban
# Processing Record 44 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 4 | marsa matruh
# Processing Record 47 of Set 4 | san pedro de ycuamandiyu
# Processing Record 48 of Set 4 | damietta
# Processing Record 49 of Set 4 | mozarlandia
# Processing Record 50 of Set 4 | qaqortoq
# Processing Record 1 of Set 5 | ust-koksa
# Processing Record 2 of Set 5 | barsovo
# Processing Record 3 of Set 5 | morristown
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | lethem
# Processing Record 7 of Set 5 | minab
# Processing Record 8 of Set 5 | lesogorskiy
# Processing Record 9 of Set 5 | yar
# Processing Record 10 of Set 5 | sao miguel do araguaia
# Processing Record 11 of Set 5 | riyadh
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | cockburn town
# Processing Record 14 of Set 5 | tshikapa
# Processing Record 15 of Set 5 | araouane
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | brandon
# Processing Record 18 of Set 5 | quatre cocos
# Processing Record 19 of Set 5 | nalut
# Processing Record 20 of Set 5 | kangaatsiaq
# Processing Record 21 of Set 5 | axim
# Processing Record 22 of Set 5 | nouakchott
# Processing Record 23 of Set 5 | zambezi
# Processing Record 24 of Set 5 | saint-leu
# Processing Record 25 of Set 5 | port blair
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | guarapari
# Processing Record 28 of Set 5 | maudaha
# Processing Record 29 of Set 5 | palmares do sul
# Processing Record 30 of Set 5 | sal rei
# Processing Record 31 of Set 5 | ipameri
# Processing Record 32 of Set 5 | joao pinheiro
# Processing Record 33 of Set 5 | albany
# Processing Record 34 of Set 5 | afua
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | tazovskiy
# Processing Record 37 of Set 5 | erlangen
# Processing Record 38 of Set 5 | verkhnyaya inta
# Processing Record 39 of Set 5 | moyo
# Processing Record 40 of Set 5 | rondonopolis
# Processing Record 41 of Set 5 | yar-sale
# Processing Record 42 of Set 5 | salo
# Processing Record 43 of Set 5 | temba
# Processing Record 44 of Set 5 | sambava
# Processing Record 45 of Set 5 | vigia
# Processing Record 46 of Set 5 | charlestown
# Processing Record 47 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 48 of Set 5 | aleksandrov gay
# Processing Record 49 of Set 5 | cabo rojo
# Processing Record 50 of Set 5 | kostomuksha
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | volkach
# Processing Record 3 of Set 6 | coihueco
# Processing Record 4 of Set 6 | lodingen
# Processing Record 5 of Set 6 | marystown
# Processing Record 6 of Set 6 | la peca
# Processing Record 7 of Set 6 | karistos
# City not found. Skipping...
# Processing Record 8 of Set 6 | chicama
# Processing Record 9 of Set 6 | catia la mar
# Processing Record 10 of Set 6 | kasba
# Processing Record 11 of Set 6 | concarneau
# Processing Record 12 of Set 6 | stornoway
# Processing Record 13 of Set 6 | oistins
# Processing Record 14 of Set 6 | sur
# Processing Record 15 of Set 6 | gamba
# Processing Record 16 of Set 6 | luxor
# Processing Record 17 of Set 6 | salta
# Processing Record 18 of Set 6 | trelew
# Processing Record 19 of Set 6 | saint-georges
# Processing Record 20 of Set 6 | ventspils
# Processing Record 21 of Set 6 | florida
# Processing Record 22 of Set 6 | dhankuta
# Processing Record 23 of Set 6 | puntarenas
# Processing Record 24 of Set 6 | aksu
# Processing Record 25 of Set 6 | alibag
# Processing Record 26 of Set 6 | santa isabel do rio negro
# Processing Record 27 of Set 6 | cordoba
# Processing Record 28 of Set 6 | atbasar
# Processing Record 29 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | baikunthpur
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | grand gaube
# Processing Record 34 of Set 6 | koygorodok
# Processing Record 35 of Set 6 | whittlesea
# Processing Record 36 of Set 6 | jaisalmer
# Processing Record 37 of Set 6 | togur
# Processing Record 38 of Set 6 | ketou
# Processing Record 39 of Set 6 | matagami
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | abu dhabi
# Processing Record 42 of Set 6 | kattivakkam
# Processing Record 43 of Set 6 | bara
# Processing Record 44 of Set 6 | wajid
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | praia
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | abu samrah
# Processing Record 50 of Set 6 | bay roberts
# Processing Record 1 of Set 7 | jalu
# Processing Record 2 of Set 7 | kudahuvadhoo
# Processing Record 3 of Set 7 | ayagoz
# Processing Record 4 of Set 7 | ponta delgada
# Processing Record 5 of Set 7 | saint-augustin
# Processing Record 6 of Set 7 | teguise
# Processing Record 7 of Set 7 | rosendal
# Processing Record 8 of Set 7 | rjukan
# Processing Record 9 of Set 7 | changji
# Processing Record 10 of Set 7 | tessalit
# Processing Record 11 of Set 7 | chapais
# Processing Record 12 of Set 7 | shiraz
# Processing Record 13 of Set 7 | kushmurun
# Processing Record 14 of Set 7 | sao filipe
# Processing Record 15 of Set 7 | zlobin
# Processing Record 16 of Set 7 | boksitogorsk
# Processing Record 17 of Set 7 | foldeak
# Processing Record 18 of Set 7 | alegrete
# Processing Record 19 of Set 7 | shupiyan
# Processing Record 20 of Set 7 | lucapa
# Processing Record 21 of Set 7 | buba
# Processing Record 22 of Set 7 | redondela
# Processing Record 23 of Set 7 | sakakah
# Processing Record 24 of Set 7 | lusambo
# Processing Record 25 of Set 7 | solwezi
# Processing Record 26 of Set 7 | humaita
# Processing Record 27 of Set 7 | les cayes
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | salinopolis
# Processing Record 30 of Set 7 | agirish
# Processing Record 31 of Set 7 | uhlove
# Processing Record 32 of Set 7 | muravlenko
# Processing Record 33 of Set 7 | konevo
# Processing Record 34 of Set 7 | mbanza-ngungu
# Processing Record 35 of Set 7 | alto araguaia
# Processing Record 36 of Set 7 | almeirim
# Processing Record 37 of Set 7 | francistown
# Processing Record 38 of Set 7 | skibbereen
# Processing Record 39 of Set 7 | taormina
# Processing Record 40 of Set 7 | lukovetskiy
# Processing Record 41 of Set 7 | mananara
# Processing Record 42 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | banikoara
# Processing Record 44 of Set 7 | aswan
# Processing Record 45 of Set 7 | savannah bight
# Processing Record 46 of Set 7 | san pedro
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | artyom
# Processing Record 49 of Set 7 | sisimiut
# Processing Record 50 of Set 7 | hvolsvollur
# Processing Record 1 of Set 8 | tapes
# Processing Record 2 of Set 8 | porto santo
# Processing Record 3 of Set 8 | kaya
# Processing Record 4 of Set 8 | belyy yar
# Processing Record 5 of Set 8 | ternitz
# Processing Record 6 of Set 8 | camocim
# Processing Record 7 of Set 8 | el astillero
# Processing Record 8 of Set 8 | san lorenzo
# Processing Record 9 of Set 8 | bonavista
# Processing Record 10 of Set 8 | goderich
# Processing Record 11 of Set 8 | nantucket
# Processing Record 12 of Set 8 | kotido
# Processing Record 13 of Set 8 | puertollano
# Processing Record 14 of Set 8 | cap malheureux
# Processing Record 15 of Set 8 | talcahuano
# Processing Record 16 of Set 8 | vesoul
# Processing Record 17 of Set 8 | narasannapeta
# Processing Record 18 of Set 8 | puerto del rosario
# Processing Record 19 of Set 8 | bar harbor
# Processing Record 20 of Set 8 | kalabo
# Processing Record 21 of Set 8 | blankenberge
# Processing Record 22 of Set 8 | grootfontein
# Processing Record 23 of Set 8 | savinskiy
# Processing Record 24 of Set 8 | ostersund
# Processing Record 25 of Set 8 | sile
# Processing Record 26 of Set 8 | werder
# Processing Record 27 of Set 8 | zwedru
# Processing Record 28 of Set 8 | lodwar
# Processing Record 29 of Set 8 | itarema
# Processing Record 30 of Set 8 | revda
# Processing Record 31 of Set 8 | sadovoye
# Processing Record 32 of Set 8 | chik
# Processing Record 33 of Set 8 | burica
# City not found. Skipping...
# Processing Record 34 of Set 8 | madingou
# Processing Record 35 of Set 8 | mahajanga
# Processing Record 36 of Set 8 | ilhabela
# Processing Record 37 of Set 8 | amapa
# Processing Record 38 of Set 8 | tibati
# Processing Record 39 of Set 8 | kankan
# Processing Record 40 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 8 | ayia galini
# Processing Record 42 of Set 8 | padang
# Processing Record 43 of Set 8 | nola
# Processing Record 44 of Set 8 | uruzgan
# Processing Record 45 of Set 8 | stepnyak
# Processing Record 46 of Set 8 | awjilah
# Processing Record 47 of Set 8 | balsas
# Processing Record 48 of Set 8 | alipur chatha
# Processing Record 49 of Set 8 | kavaratti
# Processing Record 50 of Set 8 | cetraro
# Processing Record 1 of Set 9 | thaba-tseka
# Processing Record 2 of Set 9 | mezen
# Processing Record 3 of Set 9 | azul
# Processing Record 4 of Set 9 | norton
# Processing Record 5 of Set 9 | port-gentil
# Processing Record 6 of Set 9 | mufulira
# Processing Record 7 of Set 9 | calama
# Processing Record 8 of Set 9 | tarko-sale
# Processing Record 9 of Set 9 | anloga
# Processing Record 10 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 9 | dahuk
# Processing Record 12 of Set 9 | camacha
# Processing Record 13 of Set 9 | pangnirtung
# Processing Record 14 of Set 9 | matane
# Processing Record 15 of Set 9 | samana
# Processing Record 16 of Set 9 | lake shore
# Processing Record 17 of Set 9 | xai-xai
# Processing Record 18 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 9 | kobojango
# City not found. Skipping...
# Processing Record 20 of Set 9 | toropets
# Processing Record 21 of Set 9 | bahia blanca
# Processing Record 22 of Set 9 | oxapampa
# Processing Record 23 of Set 9 | nata
# Processing Record 24 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 9 | shoranur
# Processing Record 26 of Set 9 | urengoy
# Processing Record 27 of Set 9 | chapada dos guimaraes
# Processing Record 28 of Set 9 | sawakin
# Processing Record 29 of Set 9 | aden
# Processing Record 30 of Set 9 | lima
# Processing Record 31 of Set 9 | pero pinheiro
# Processing Record 32 of Set 9 | bolu
# Processing Record 33 of Set 9 | yambio
# Processing Record 34 of Set 9 | luleburgaz
# Processing Record 35 of Set 9 | arlit
# Processing Record 36 of Set 9 | bridgetown
# Processing Record 37 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 9 | catamarca
# Processing Record 39 of Set 9 | manavgat
# Processing Record 40 of Set 9 | raga
# Processing Record 41 of Set 9 | metsovon
# City not found. Skipping...
# Processing Record 42 of Set 9 | nahrin
# Processing Record 43 of Set 9 | akdagmadeni
# Processing Record 44 of Set 9 | ormara
# Processing Record 45 of Set 9 | moyale
# Processing Record 46 of Set 9 | kisangani
# Processing Record 47 of Set 9 | havre-saint-pierre
# Processing Record 48 of Set 9 | mitsamiouli
# Processing Record 49 of Set 9 | lokoja
# Processing Record 50 of Set 9 | raudeberg
# Processing Record 1 of Set 10 | arauco
# Processing Record 2 of Set 10 | san rafael
# Processing Record 3 of Set 10 | ossipee
# Processing Record 4 of Set 10 | azuaga
# Processing Record 5 of Set 10 | vuktyl
# Processing Record 6 of Set 10 | alenquer
# Processing Record 7 of Set 10 | chatsu
# City not found. Skipping...
# Processing Record 8 of Set 10 | miquelon
# Processing Record 9 of Set 10 | maceio
# Processing Record 10 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 10 | virginia beach
# Processing Record 12 of Set 10 | inongo
# Processing Record 13 of Set 10 | la asuncion
# Processing Record 14 of Set 10 | kulu
# Processing Record 15 of Set 10 | strezhevoy
# Processing Record 16 of Set 10 | agua branca
# Processing Record 17 of Set 10 | marfino
# Processing Record 18 of Set 10 | nuuk
# Processing Record 19 of Set 10 | karpathos
# Processing Record 20 of Set 10 | bustonkala
# City not found. Skipping...
# Processing Record 21 of Set 10 | canto do buriti
# Processing Record 22 of Set 10 | ambovombe
# Processing Record 23 of Set 10 | sesheke
# Processing Record 24 of Set 10 | atasu
# Processing Record 25 of Set 10 | marevo
# Processing Record 26 of Set 10 | faro
# Processing Record 27 of Set 10 | igarka
# Processing Record 28 of Set 10 | kentau
# Processing Record 29 of Set 10 | sao joaquim
# Processing Record 30 of Set 10 | abeche
# Processing Record 31 of Set 10 | derbent
# Processing Record 32 of Set 10 | bentiu
# Processing Record 33 of Set 10 | galbshtadt
# Processing Record 34 of Set 10 | scarborough
# Processing Record 35 of Set 10 | rognan
# Processing Record 36 of Set 10 | olinda
# Processing Record 37 of Set 10 | meulaboh
# Processing Record 38 of Set 10 | kalengwa
# Processing Record 39 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 10 | ardrishaig
# Processing Record 41 of Set 10 | polunochnoye
# Processing Record 42 of Set 10 | tripoli
# Processing Record 43 of Set 10 | oksfjord
# Processing Record 44 of Set 10 | kidal
# Processing Record 45 of Set 10 | bastia
# Processing Record 46 of Set 10 | hofn
# Processing Record 47 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 10 | abha
# Processing Record 50 of Set 10 | husavik
# Processing Record 1 of Set 11 | jaque
# Processing Record 2 of Set 11 | jega
# Processing Record 3 of Set 11 | gat
# Processing Record 4 of Set 11 | souillac
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | gornopravdinsk
# Processing Record 7 of Set 11 | vyyezdnoye
# Processing Record 8 of Set 11 | goya
# Processing Record 9 of Set 11 | coihaique
# Processing Record 10 of Set 11 | honningsvag
# Processing Record 11 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 12 of Set 11 | aviles
# Processing Record 13 of Set 11 | bria
# Processing Record 14 of Set 11 | port-cartier
# Processing Record 15 of Set 11 | razole
# Processing Record 16 of Set 11 | bonthe
# Processing Record 17 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 11 | leticia
# Processing Record 19 of Set 11 | shache
# Processing Record 20 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 11 | kulhudhuffushi
# Processing Record 22 of Set 11 | halvad
# Processing Record 23 of Set 11 | mokolo
# Processing Record 24 of Set 11 | veraval
# Processing Record 25 of Set 11 | gilgit
# Processing Record 26 of Set 11 | aracoiaba
# Processing Record 27 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 29 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 30 of Set 11 | richards bay
# Processing Record 31 of Set 11 | camopi
# Processing Record 32 of Set 11 | gari
# Processing Record 33 of Set 11 | queenstown
# Processing Record 34 of Set 11 | millbury
# Processing Record 35 of Set 11 | morbegno
# Processing Record 36 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 11 | paraibano
# Processing Record 38 of Set 11 | krasnyy oktyabr
# Processing Record 39 of Set 11 | concepcion
# Processing Record 40 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 11 | kasungu
# Processing Record 42 of Set 11 | lebu
# Processing Record 43 of Set 11 | inta
# Processing Record 44 of Set 11 | bongandanga
# Processing Record 45 of Set 11 | beyneu
# Processing Record 46 of Set 11 | luau
# Processing Record 47 of Set 11 | tutoia
# Processing Record 48 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 11 | ewo
# Processing Record 50 of Set 11 | moengo
# Processing Record 1 of Set 12 | takaungu
# Processing Record 2 of Set 12 | zeist
# Processing Record 3 of Set 12 | poselki
# Processing Record 4 of Set 12 | gewane
# Processing Record 5 of Set 12 | naryan-mar
# Processing Record 6 of Set 12 | aksarka
# Processing Record 7 of Set 12 | oxelosund
# Processing Record 8 of Set 12 | carauari
# Processing Record 9 of Set 12 | abnub
# Processing Record 10 of Set 12 | soyo
# Processing Record 11 of Set 12 | sussex
# Processing Record 12 of Set 12 | tukrah
# Processing Record 13 of Set 12 | melfi
# Processing Record 14 of Set 12 | aasiaat
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | boditi
# Processing Record 17 of Set 12 | kisanga
# Processing Record 18 of Set 12 | den helder
# Processing Record 19 of Set 12 | sao borja
# Processing Record 20 of Set 12 | boo
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | ugoofaaru
# Processing Record 23 of Set 12 | bealanana
# Processing Record 24 of Set 12 | vestmanna
# Processing Record 25 of Set 12 | tarnogskiy gorodok
# Processing Record 26 of Set 12 | marathon
# Processing Record 27 of Set 12 | waddan
# Processing Record 28 of Set 12 | maragogi
# Processing Record 29 of Set 12 | fort-shevchenko
# Processing Record 30 of Set 12 | rawson
# Processing Record 31 of Set 12 | babadag
# Processing Record 32 of Set 12 | naliya
# Processing Record 33 of Set 12 | urucara
# Processing Record 34 of Set 12 | lebyazhye
# Processing Record 35 of Set 12 | tonota
# Processing Record 36 of Set 12 | ribas do rio pardo
# Processing Record 37 of Set 12 | kamenka
# Processing Record 38 of Set 12 | viedma
# Processing Record 39 of Set 12 | jawhar
# Processing Record 40 of Set 12 | kolosovka
# Processing Record 41 of Set 12 | uberaba
# Processing Record 42 of Set 12 | carutapera
# Processing Record 43 of Set 12 | cerrito
# Processing Record 44 of Set 12 | imbituba
# Processing Record 45 of Set 12 | aranos
# Processing Record 46 of Set 12 | butterworth
# Processing Record 47 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 12 | galle
# Processing Record 49 of Set 12 | ratnapura
# Processing Record 50 of Set 12 | fakel
# Processing Record 1 of Set 13 | goure
# Processing Record 2 of Set 13 | road town
# Processing Record 3 of Set 13 | opuwo
# Processing Record 4 of Set 13 | dunda
# Processing Record 5 of Set 13 | le port
# Processing Record 6 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 7 of Set 13 | sao felix do xingu
# Processing Record 8 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 13 | puerto armuelles
# Processing Record 10 of Set 13 | lisakovsk
# Processing Record 11 of Set 13 | muzhi
# Processing Record 12 of Set 13 | margate
# Processing Record 13 of Set 13 | tanhacu
# Processing Record 14 of Set 13 | ruswil
# Processing Record 15 of Set 13 | muisne
# Processing Record 16 of Set 13 | puunsi
# City not found. Skipping...
# Processing Record 17 of Set 13 | calabozo
# Processing Record 18 of Set 13 | acari
# Processing Record 19 of Set 13 | benguela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 569

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux -20.3428   57.7575     73.65        68          40
# 1           Dikson  73.5069   80.5464     -8.70       100          96
# 2        Cape Town -33.9258   18.4232     63.88        90          75
# 3       Oskarshamn  57.2645   16.4484     48.99        92          27
# 4       Banda Aceh   5.5577   95.3222     76.01        91         100
# 5   Port Elizabeth -33.9180   25.5701     64.69        89         100
# 6        Inhambane -23.8650   35.3833     77.45        85           9
# 7         Hermanus -34.4187   19.2345     64.80        87           0
# 8        Busselton -33.6500  115.3333     53.33        75          79
# 9         Buncrana  55.1333   -7.4500     54.21        86         100
#
#    Wind Speed Country      Current Description                 Date
# 0        3.44      MU         scattered clouds  2022-11-12 20:55:00
# 1        5.50      RU          overcast clouds  2022-11-12 20:55:00
# 2        5.75      ZA  light intensity drizzle  2022-11-12 20:51:32
# 3        5.53      SE         scattered clouds  2022-11-12 20:55:01
# 4        8.77      ID               light rain  2022-11-12 20:55:01
# 5        5.99      ZA     heavy intensity rain  2022-11-12 20:50:51
# 6        9.46      MZ                clear sky  2022-11-12 20:55:02
# 7       12.35      ZA               light rain  2022-11-12 20:54:13
# 8       10.92      AU            broken clouds  2022-11-12 20:55:02
# 9       15.23      IE          overcast clouds  2022-11-12 20:55:03

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
df = city_data_df[new_column_order]

# Display sample data
df.head()
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428  57.7575     73.65        68          40
# 1           Dikson      RU  73.5069  80.5464     -8.70       100          96
# 2        Cape Town      ZA -33.9258  18.4232     63.88        90          75
# 3       Oskarshamn      SE  57.2645  16.4484     48.99        92          27
# 4       Banda Aceh      ID   5.5577  95.3222     76.01        91         100
#
#    Wind Speed      Current Description
# 0        3.44         scattered clouds
# 1        5.50          overcast clouds
# 2        5.75  light intensity drizzle
# 3        5.53         scattered clouds
# 4        8.77               light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE

output_data_file = "weather_database/WeatherPy_Database.csv"
df.to_csv(output_data_file, index_label="City_ID")
